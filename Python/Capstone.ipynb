# %%
import pandas as pd
import numpy as np

# %%
category_df=pd.read_csv('category_DVD Rental.csv')
category_df
# Out:
#     category_id   name  last_update
# 0         False  False        False
# 1         False  False        False
# 2         False  False        False
# 3         False  False        False
# 4         False  False        False
# 5         False  False        False
# 6         False  False        False
# 7         False  False        False
# 8         False  False        False
# 9         False  False        False
# 10        False  False        False
# 11        False  False        False
# 12        False  False        False
# 13        False  False        False
# 14        False  False        False
# 15        False  False        False

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\milankumar.parikh'

# %%
category_df.to_csv('category(c).csv')

# %%
film_category_df = pd.read_csv('film_category_DVD Rental.csv')
film_category_df.isnull().sum()
film_category_df.to_csv('film_category(c).csv')

# %%
film_df=pd.read_csv('film_DVD Rental.csv')
film_df.isnull().sum()
film_df.to_csv('film(c).csv')

# %%
inventory_df=pd.read_csv('inventory_DVD Rental.csv')
inventory_df.isnull().sum()
inventory_df.to_csv('inventory(c).csv')

# %%
rental_df=pd.read_csv('rental_DVD Rental.csv')
rental_df.isnull().sum()
rental_df.to_csv('rental(c).csv')

# %%
payment_df=pd.read_csv('payment_DVD Rental.csv')
payment_df.isnull().sum()
payment_df.to_csv('payment(c).csv')

# %%
language_df = pd.read_csv('language_DVD Rental.csv')
language_df.isnull().sum()
language_df.to_csv('language(c).csv')

# %%
film_actor_df=pd.read_csv('film_actor_DVD Rental.csv')
film_actor_df.isnull().sum()
film_actor_df.to_csv('film_actor(c).csv')

# %%
staff_df=pd.read_csv('staff_DVD Rental.csv')
staff_df.isnull().sum()
staff_df.to_csv('staff(c).csv')

# %%
# actor_df = pd.read_csv('Actor_DVD Rental.csv')
# actor_df.isnull().sum()

# %%
customer_df = pd.read_csv('customer_DVD Rental.csv')
customer_df.isnull().sum()
customer_df.to_csv('customer(c).csv')

# %%
address_df=pd.read_csv('address_DVD Rental.csv')
address_df.isnull().sum()
address_df.to_csv('address(c).csv')

# %%
city_df=pd.read_csv('city_DVD Rental.csv')
city_df.isnull().sum()
city_df.to_csv('city(c).csv')

# %%
country_df=pd.read_csv('country_DVD Rental.csv')
country_df.isnull().sum()
country_df.to_csv('country(c).csv')

# %%
store_df=pd.read_csv('store_DVD Rental.csv')
store_df.isnull().sum()
store_df.to_csv('store(c).csv')

# %%
final_table = category_df.merge(film_category_df,on='category_id').merge(film_df,on='film_id').merge(inventory_df,on='film_id').merge(rental_df,on='inventory_id').merge(payment_df,on='rental_id')
final_table
# Out:
# C:\Users\milankumar.parikh\AppData\Local\Temp\ipykernel_20812\379394496.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'last_update_x'} in the result is deprecated and will raise a MergeError in a future version.
#   final_table = category_df.merge(film_category_df,on='category_id').merge(film_df,on='film_id').merge(inventory_df,on='film_id').merge(rental_df,on='inventory_id').merge(payment_df,on='rental_id')
#        category_id    name   last_update_x  film_id    last_update_y  \
# 0                1  Action  2/15/2006 9:46       19  2/15/2006 10:07
# 1                1  Action  2/15/2006 9:46       19  2/15/2006 10:07
# 2                1  Action  2/15/2006 9:46       19  2/15/2006 10:07
# 3                1  Action  2/15/2006 9:46       19  2/15/2006 10:07
# 4                1  Action  2/15/2006 9:46       19  2/15/2006 10:07
# ...            ...     ...             ...      ...              ...
# ...

# %%
final_table.shape
# Out:
# (14596, 31)

# %%
final_table.columns
# Out:
# Index(['category_id', 'name', 'last_update_x', 'film_id', 'last_update_y',
#        'title', 'description', 'release_year', 'language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'last_update_x', 'special_features', 'fulltext',
#        'inventory_id', 'store_id', 'last_update_y', 'rental_id', 'rental_date',
#        'customer_id_x', 'return_date', 'staff_id_x', 'last_update',
#        'payment_id', 'customer_id_y', 'staff_id_y', 'amount', 'payment_date'],
#       dtype='object')

# %%
final_table.isnull().sum()
# Out:
# category_id           0
# name                  0
# last_update_x         0
# film_id               0
# last_update_y         0
# title                 0
# description           0
# release_year          0
# language_id           0
# rental_duration       0
# rental_rate           0
# length                0
# replacement_cost      0
# rating                0
# last_update_x         0
# special_features      0
# fulltext              0
# inventory_id          0
# store_id              0
# last_update_y         0
# rental_id             0
# rental_date           0
# customer_id_x         0
# return_date         183
# staff_id_x            0
# last_update           0
# payment_id            0
# customer_id_y         0
# staff_id_y            0
# amount                0
# payment_date          0
# dtype: int64

# %%
final_table.to_csv('final_table.csv')
